# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers, layers, Sequential
from tensorflow.keras.layers import Input, Dense, LeakyReLU,Conv1D,Dropout,MaxPooling1D, LocallyConnected1D
from tensorflow.keras.layers import Flatten,ReLU, BatchNormalization,GlobalAveragePooling1D, LSTM
import numpy as np

def runif():
    return tf.random.uniform([1], dtype=tf.float64)[0]
    # return tf.constant(.8, tf.float32)

def rexp(): # exp(1)
    return -tf.math.log(runif())



def exprelu(x):
    return tf.where(x > 0, tf.math.expm1(x), tf.zeros_like(x))

def reloid(x):
    "(sigma(x[1]), ..., sigma(x[-2]), relu(x[-1])"
    return tf.concat([tf.nn.sigmoid(x[:-1]), tf.math.exp(x[-1:])], axis=0)

def reloid_derivative(x):
    return tf.concat(
        [
            tf.nn.sigmoid(x[:-1])
            * (1 - tf.nn.sigmoid(x[:-1])),  # derivative of sigmoid
            tf.math.exp(x[-1:]),
        ],
        axis=0,
    )

def S(x, w, v, b):
    """
    x: scalar
    w, v, b: (3, H)
    """
    x = tf.convert_to_tensor(x, dtype="float64")
    # tf.debugging.assert_positive(x, message="R: x>0")
    exp_w_v = tf.math.exp([w, v])
    ew = exp_w_v[0]
    ev = exp_w_v[1]
    # b = tf.math.sigmoid(b) # try this  # JT - bug. was sigb
    ew = tf.concat([ew[:-1], tf.ones_like(ew[-1:]),], axis=0,)
    x = tf.reshape(x, (1, 1))
    return tf.transpose(ev) @ reloid(ew @ x + b)

@tf.function
def R(x, w, v, b):
    return S(tf.math.log(x), w, v, b)

@tf.function
def Rinv(y, w, v, b):
    y = tf.convert_to_tensor(y, dtype="float64")
    # y = tf.reshape(y, (-1,))[0]
    # as x -> oo, R is asymyptotic to exp(v[-1] + w[-1]) x
    # fixme: calculate this exactly.
    x_left = tf.convert_to_tensor([[0.0]], tf.float64)
    x_right = tf.convert_to_tensor([[1e8]], tf.float64)
    # tf.print((x_left, x_right))
    # tf.print("y", y)
    # tf.print('y',y)
    # tf.debugging.assert_greater(R(x_right, w, v, b), y, message="R(x_right)>y inv")

    def cond(xl, xr):
        # tf.print(xl, xr)
        xi = (xl + xr) / 2.0
        yi = R(xi, w, v, b)[0, 0]
        return abs(y - yi) > 1e-6

    def body(xl, xr):
        xi = (xl + xr) / 2.0
        yi = R(xi, w, v, b)[0, 0]
        left = tf.cast(yi < y, dtype="float64")
        xl = left * xi + (1.0 - left) * xl
        xr = (1.0 - left) * xi + left * xr
        return (xl, xr)
        # print(y, x_i, y_i)

    xl, xr = tf.while_loop(cond, body, (x_left, x_right))
    return (xl + xr) / 2.0

@tf.custom_gradient
def custom_Rinv(y, w, v, b):
    y = tf.convert_to_tensor(y, dtype="float64")
    x = Rinv(y, w, v, b)
    with tf.GradientTape() as g:
        g.watch([x, w, v, b])
        y = R(x, w, v, b)
    dR_dw, dR_dv, dR_db, dR_dx = g.gradient(y, [w, v, b, x])

    def grad(dx):
        return dx / dR_dx, -dx * dR_dw / dR_dx, -dx * dR_dv / dR_dx, -dx * dR_db / dR_dx

    return x, grad

mu = 1e-4
rho = 1e-5

def _gen_gaps(k: int, _R, _Rinv,) -> tf.Tensor:
    """Return k gaps sampled from genetic distribution with rate function eta."""
    z = tf.convert_to_tensor([[rexp()]])
    x = _Rinv(z)  # initialize x by sampling from prior
    tf.debugging.assert_positive(x, message="gen_gaps first x")

    gap = tf.constant([[0.0]], dtype=tf.float64)
    j = 0
    ta = tf.TensorArray(tf.float64, size=k + 1)

    while tf.less(j, k + 1):
        # x' satisfies R(x') - R(u*x) = Z => x' = Rinv(Z + R(u*x))
        u = runif()
        z = rexp()
        u_x = tf.convert_to_tensor([[u * x]])
        r_u_x = _R(u_x)  # compute R(u_x)
        x = _Rinv(z + r_u_x)  # segment height
        # tf.print(x)
        # tf.print(z+r_u_x,"\n")
        with tf.control_dependencies(
            [
                tf.debugging.assert_all_finite(x, "second x"),
                tf.debugging.assert_positive(x, message="gen_gaps second x"),
            ]
        ):
            next_event = rexp() / (x * (mu + rho))
            tf.debugging.assert_positive(next_event, message="gen_gaps first gap")
            gap += next_event  # length to next event
        while runif() < (mu / (mu + rho)) and tf.less(j, k + 1):
            ta = ta.write(j, gap)
            gap *= 0.0
            j += 1
            next_event = rexp() / (x * (mu + rho))
            tf.debugging.assert_positive(next_event, message="gen_gaps second gap")
            gap += next_event  # length to next event

    gaps = ta.stack()[1:]  # first obs suffers from inspection paradox?
    with tf.control_dependencies(
        [
            tf.debugging.assert_positive(
                gaps, message="gaps have non-positive entry", summarize=100
            )
        ]
    ):
        return gaps


def R_learned(x, generator):
    return R(x, generator.weights[0], generator.weights[1], generator.weights[2])

thresh = tf.constant([1e-1], dtype="float64", shape=(1,))

def eta(x):
    x = tf.cast(x, "float64")
    one = tf.ones(shape=[1,], dtype="float64",)
    return tf.cast(tf.where(x < thresh, 1 / 100, one), "float64")

def R_real(x):
    """R_real(x) = integral_0^x eta(t) dt"""
    x = tf.cast(x, "float64")
    x = tf.reshape(x, (1, tf.size(x)))
    tf.debugging.assert_positive(x, message="R_real: x>0")
    return tf.cast(
        tf.where(x < thresh, x / 100.0, thresh / 100.0 + (x - thresh)), "float64"
    )
    # return x


def R_real_inv(y):
    y = tf.cast(y, "float64")
    tf.debugging.assert_positive(y, message="R_real: x>0")
    return tf.cast(
        tf.where(y < thresh / 100.0, y * 100.0, y - (thresh / 100.0 - thresh)),
        "float64",
    )

@tf.function
def gen_gaps(
    w, v, b, k,
):
    R_ = lambda x: R(x, w, v, b)
    Rinv_ = lambda z: custom_Rinv(z, w, v, b)
    return _gen_gaps(k, R_, Rinv_)

@tf.function
def gen_gaps_real(k: int,):
    return _gen_gaps(k, R_real, R_real_inv,)

def discriminator_objective(d_x, g_z):
    """
    d_x = real output
    g_z = fake output
    """
    real_loss = cross_entropy(
        tf.ones_like(d_x), d_x
    )  # If we feed the discriminator with real images, we assume they all are the right pictures --> Because of that label == 1
    fake_loss = cross_entropy(
        tf.zeros_like(g_z), g_z
    )  # Each noise we feed in are fakes image --> Because of that labels are 0
    total_loss = real_loss + fake_loss

    return total_loss

# %%
m = tf.keras.metrics.BinaryAccuracy()
# @tf.function
def training_step(discriminator):
    with tf.GradientTape() as disc_tape:
        # both fake and real seq have shape [Batch_size, seq_len, 1]
        one_fake = tf.stack([tf.stack([tf.squeeze(gen_gaps(w, v, b, 224)) for _ in range(224)]) for _ in range(3)], 2)
        fake_seq = tf.stack([one_fake for _ in range(batch_size)], 0)
        
        one_real = tf.stack([tf.stack([tf.squeeze(gen_gaps_real(224)) for _ in range(224)]) for _ in range(3)], 2)
        real_seq = tf.stack([one_real for _ in range(batch_size)], 0)

        d_x_true = discriminator(tf.math.log(real_seq))
        d_x_fake = discriminator(tf.math.log(fake_seq))
        
        discriminator_loss = discriminator_objective(d_x_true, d_x_fake)
        # Adjusting Gradient of Discriminator
        gradients_of_discriminator = disc_tape.gradient(
            discriminator_loss, discriminator.trainable_variables
        )
        discriminator_optimizer.apply_gradients(
            zip(gradients_of_discriminator, discriminator.trainable_variables)
        )  # Takes a list of gradient and variables pairs
    m.reset_states()
    m.update_state(tf.ones_like(d_x_true),tf.math.sigmoid(d_x_true))
    real_acc = m.result()

    m.reset_states()
    m.update_state(tf.zeros_like(d_x_fake),tf.math.sigmoid(d_x_fake))
    fake_acc = m.result()

    return discriminator_loss, real_acc, fake_acc
  
def training(epoches):
    for epoch in range(epoches + 1):
        disc_loss,real,fake = training_step(discriminator)
        d_loss.append(disc_loss)
        real_acc.append(real)
        fake_acc.append(fake)
        print("epoch=%d discriminator_loss=%f real_acc=%f fake_acc=%f"
                % (epoch, disc_loss, real, fake))

cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
seq_len = 800
learning_rate = 0.005
batch_size = 64
EPOCHES = 500
discriminator_optimizer = optimizers.Adam(learning_rate)

# %%
#upload weights.csv to colab
w,v,b=np.loadtxt('weights.csv',delimiter=',')
w = tf.expand_dims(w,-1)
v = tf.expand_dims(v,-1)
b = tf.expand_dims(b,-1)

# %%
import matplotlib.pyplot as plt
x = tf.math.log(gen_gaps(w, v, b, 1000))
y = tf.math.log(gen_gaps_real(1000))
plt.hist(x.numpy().reshape(-1),label = 'fake')
plt.hist(y.numpy().reshape(-1), alpha=0.4,label='real')
plt.legend()
plt.show()

# %%
x = gen_gaps(w, v, b, 1000)
y = gen_gaps_real(1000)
plt.hist(x.numpy().reshape(-1),label = 'fake')
plt.hist(y.numpy().reshape(-1), alpha=0.4,label='real')
plt.legend()
plt.show()

# %%
# seq_len = 100
# batch_size = 1000
# random = tf.random.normal([1,seq_len],dtype=tf.float64)

# fake = tf.reshape(tf.stack([gen_gaps(w, v, b, seq_len) for _ in range(batch_size)]),[batch_size,seq_len,1])
# fake_dis = [random @ i for i in fake]

# real = tf.reshape(tf.stack([tf.reshape(gen_gaps_real(seq_len), (1, seq_len))\
#                                       for _ in range(batch_size)]),[batch_size,seq_len,1])
# real_dis = [random @ i for i in real]

# %%
inputs = Input(shape=(224,224,3))
model = tf.keras.applications.EfficientNetB0(input_tensor=inputs, weights=None,include_top=False)
x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
x = layers.BatchNormalization()(x)
outputs = Dense(1)(x)
discriminator = tf.keras.Model(inputs, outputs, name="discriminator")

discriminator.summary()
# Out:
# Model: "discriminator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 224, 224, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 224, 224, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 112, 112, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 112, 112, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 112, 112, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 112, 112, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 112, 112, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 112, 112, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 112, 112, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 112, 112, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 112, 112, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 112, 112, 96) 1536        block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 112, 112, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 112, 112, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 113, 113, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 56, 56, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 56, 56, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 56, 56, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 56, 56, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 56, 56, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 56, 56, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 56, 56, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 56, 56, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 56, 56, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 56, 56, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 56, 56, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 56, 56, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 56, 56, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 56, 56, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 56, 56, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 56, 56, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 56, 56, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 56, 56, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 59, 59, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 28, 28, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 28, 28, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 28, 28, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 28, 28, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 28, 28, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 28, 28, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 28, 28, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 28, 28, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 28, 28, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 28, 28, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 28, 28, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 28, 28, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 28, 28, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 28, 28, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 28, 28, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 28, 28, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 28, 28, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 28, 28, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 29, 29, 240)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 14, 14, 240)  2160        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 14, 14, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 14, 14, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 14, 14, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 14, 14, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 14, 14, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 14, 14, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 14, 14, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 14, 14, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 14, 14, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 14, 14, 80)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 14, 14, 80)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 14, 14, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 14, 14, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 14, 14, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 14, 14, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 14, 14, 80)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 14, 14, 80)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 14, 14, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 14, 14, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 14, 14, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 14, 14, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 14, 14, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 14, 14, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 14, 14, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 14, 14, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 14, 14, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 14, 14, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 14, 14, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 14, 14, 112)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 14, 14, 112)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 14, 14, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 14, 14, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 14, 14, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 14, 14, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 14, 14, 112)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 14, 14, 112)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block6a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 14, 14, 672)  0           block6a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 17, 17, 672)  0           block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv (DepthwiseConv2D (None, 7, 7, 672)    16800       block6a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 7, 7, 672)    2688        block6a_dwconv[0][0]
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 7, 7, 672)    0           block6a_bn[0][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[0][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6a_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block6a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6a_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block6a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 7, 7, 672)    0           block6a_activation[0][0]
#                                                                  block6a_se_expand[0][0]
# __________________________________________________________________________________________________
# block6a_project_conv (Conv2D)   (None, 7, 7, 192)    129024      block6a_se_excite[0][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 7, 7, 192)    768         block6a_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 7, 7, 1152)   0           block6b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6b_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6b_dwconv[0][0]
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 7, 7, 1152)   0           block6b_bn[0][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[0][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6b_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6b_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6b_activation[0][0]
#                                                                  block6b_se_expand[0][0]
# __________________________________________________________________________________________________
# block6b_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6b_se_excite[0][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 7, 7, 192)    768         block6b_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 7, 7, 192)    0           block6b_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 7, 7, 192)    0           block6b_drop[0][0]
#                                                                  block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6b_add[0][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 7, 7, 1152)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 7, 7, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 7, 7, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 7, 7, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 7, 7, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 7, 7, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 7, 7, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 7, 7, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 7, 7, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 7, 7, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 7, 7, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 7, 7, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 7, 7, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 7, 7, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 7, 7, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 7, 7, 1280)   409600      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 7, 7, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 7, 7, 1280)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1280)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1280)         5120        avg_pool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1281        batch_normalization[0][0]
# ==================================================================================================
# Total params: 4,055,972
# Trainable params: 4,011,389
# Non-trainable params: 44,583
# __________________________________________________________________________________________________

# %%
# discriminator = Sequential(
#     [
#      Input(shape=(seq_len,1)),
        
#      LocallyConnected1D(512, 4),
#      ReLU(),
#      MaxPooling1D(),
        
#      LocallyConnected1D(256, 4),
#      ReLU(),
#      MaxPooling1D(),
        
#      LocallyConnected1D(128, 4),
#      ReLU(),
#      MaxPooling1D(),
        
#      LocallyConnected1D(64, 4),
#      ReLU(),
#      MaxPooling1D(),
        
#      LocallyConnected1D(32, 4),
#      ReLU(),
#      MaxPooling1D(),
#      LSTM(30, return_sequences=True),
#      LSTM(20, return_sequences=True),
#      LSTM(10),
#      LocallyConnected1D(16, 4),
#      ReLU(),
#      MaxPooling1D(),
    
#      LocallyConnected1D(8, 4),
#      ReLU(),
#      MaxPooling1D(),
    
#      Dense(1)
#     ],
#     name="discriminator",
# )
# discriminator.summary()

# %%
d_loss = []
real_acc = []
fake_acc = []
training(EPOCHES)
# Out:
# epoch=0 discriminator_loss=1.386294 real_acc=1.000000 fake_acc=0.000000
# epoch=1 discriminator_loss=1.386294 real_acc=0.000000 fake_acc=1.000000
# epoch=2 discriminator_loss=1.396870 real_acc=1.000000 fake_acc=0.000000
# epoch=3 discriminator_loss=1.386317 real_acc=0.000000 fake_acc=1.000000
# epoch=4 discriminator_loss=1.386295 real_acc=0.000000 fake_acc=1.000000
# epoch=5 discriminator_loss=1.395627 real_acc=1.000000 fake_acc=0.000000
# epoch=6 discriminator_loss=1.570615 real_acc=0.000000 fake_acc=1.000000
# epoch=7 discriminator_loss=1.467849 real_acc=1.000000 fake_acc=0.000000
# epoch=8 discriminator_loss=1.470344 real_acc=0.000000 fake_acc=1.000000
# epoch=9 discriminator_loss=1.387762 real_acc=0.000000 fake_acc=1.000000
# epoch=10 discriminator_loss=1.386294 real_acc=1.000000 fake_acc=0.000000
# epoch=11 discriminator_loss=1.389275 real_acc=0.000000 fake_acc=1.000000
# epoch=12 discriminator_loss=1.444496 real_acc=1.000000 fake_acc=0.000000
# epoch=13 discriminator_loss=1.500905 real_acc=0.000000 fake_acc=1.000000
# epoch=14 discriminator_loss=4.313986 real_acc=1.000000 fake_acc=0.000000
# epoch=15 discriminator_loss=1.431700 real_acc=1.000000 fake_acc=0.000000
# epoch=16 discriminator_loss=1.386298 real_acc=1.000000 fake_acc=0.000000
# epoch=17 discriminator_loss=1.386559 real_acc=1.000000 fake_acc=0.000000
# epoch=18 discriminator_loss=1.413679 real_acc=0.000000 fake_acc=1.000000
# epoch=19 discriminator_loss=7.730168 real_acc=1.000000 fake_acc=0.000000
# epoch=20 discriminator_loss=1.386328 real_acc=0.000000 fake_acc=1.000000
# epoch=21 discriminator_loss=2.067750 real_acc=0.000000 fake_acc=1.000000
# epoch=22 discriminator_loss=1.537582 real_acc=0.000000 fake_acc=1.000000
# epoch=23 discriminator_loss=1.407302 real_acc=1.000000 fake_acc=0.000000
# epoch=24 discriminator_loss=3.372147 real_acc=0.000000 fake_acc=1.000000
# epoch=25 discriminator_loss=93.460899 real_acc=0.000000 fake_acc=1.000000
# epoch=26 discriminator_loss=16.703552 real_acc=0.000000 fake_acc=1.000000
# epoch=27 discriminator_loss=1.886933 real_acc=1.000000 fake_acc=0.000000
# epoch=28 discriminator_loss=4.882483 real_acc=0.000000 fake_acc=1.000000
# epoch=29 discriminator_loss=1.451413 real_acc=1.000000 fake_acc=0.000000
# epoch=30 discriminator_loss=15.135129 real_acc=0.000000 fake_acc=1.000000
# epoch=31 discriminator_loss=1.411901 real_acc=1.000000 fake_acc=0.000000
# epoch=32 discriminator_loss=1.546119 real_acc=1.000000 fake_acc=0.000000
# epoch=33 discriminator_loss=1.549276 real_acc=1.000000 fake_acc=0.000000
# epoch=34 discriminator_loss=1.387872 real_acc=1.000000 fake_acc=0.000000
# epoch=35 discriminator_loss=1.509318 real_acc=0.000000 fake_acc=1.000000
# epoch=36 discriminator_loss=1.499405 real_acc=0.000000 fake_acc=1.000000
# epoch=37 discriminator_loss=1.389411 real_acc=1.000000 fake_acc=0.000000
# epoch=38 discriminator_loss=1.535468 real_acc=1.000000 fake_acc=0.000000
# epoch=39 discriminator_loss=1.390003 real_acc=0.000000 fake_acc=1.000000
# epoch=40 discriminator_loss=1.397934 real_acc=0.000000 fake_acc=1.000000
# epoch=41 discriminator_loss=1.430098 real_acc=1.000000 fake_acc=0.000000
# epoch=42 discriminator_loss=1.389657 real_acc=0.000000 fake_acc=1.000000
# epoch=43 discriminator_loss=1.406083 real_acc=0.000000 fake_acc=1.000000
# epoch=44 discriminator_loss=1.391773 real_acc=1.000000 fake_acc=0.000000
# epoch=45 discriminator_loss=1.387396 real_acc=1.000000 fake_acc=0.000000
# epoch=46 discriminator_loss=1.398910 real_acc=0.000000 fake_acc=1.000000
# epoch=47 discriminator_loss=1.388025 real_acc=1.000000 fake_acc=0.000000
# epoch=48 discriminator_loss=1.388306 real_acc=1.000000 fake_acc=0.000000
# epoch=49 discriminator_loss=1.394277 real_acc=0.000000 fake_acc=1.000000
# epoch=50 discriminator_loss=1.387414 real_acc=1.000000 fake_acc=0.000000
# epoch=51 discriminator_loss=1.388757 real_acc=1.000000 fake_acc=0.000000
# epoch=52 discriminator_loss=1.399739 real_acc=0.000000 fake_acc=1.000000
# epoch=53 discriminator_loss=1.387383 real_acc=1.000000 fake_acc=0.000000
# epoch=54 discriminator_loss=1.389549 real_acc=1.000000 fake_acc=0.000000
# epoch=55 discriminator_loss=1.392431 real_acc=0.000000 fake_acc=1.000000
# epoch=56 discriminator_loss=1.391742 real_acc=1.000000 fake_acc=0.000000
# epoch=57 discriminator_loss=1.394045 real_acc=0.000000 fake_acc=1.000000
# epoch=58 discriminator_loss=1.386974 real_acc=1.000000 fake_acc=0.000000
# epoch=59 discriminator_loss=1.387619 real_acc=1.000000 fake_acc=0.000000
# epoch=60 discriminator_loss=1.389291 real_acc=0.000000 fake_acc=1.000000
# epoch=61 discriminator_loss=1.386296 real_acc=1.000000 fake_acc=0.000000
# epoch=62 discriminator_loss=1.391634 real_acc=1.000000 fake_acc=0.000000
# epoch=63 discriminator_loss=1.387526 real_acc=0.000000 fake_acc=1.000000
# epoch=64 discriminator_loss=1.386605 real_acc=0.000000 fake_acc=1.000000
# epoch=65 discriminator_loss=1.392628 real_acc=1.000000 fake_acc=0.000000
# epoch=66 discriminator_loss=1.399839 real_acc=0.000000 fake_acc=1.000000
# epoch=67 discriminator_loss=1.386474 real_acc=0.000000 fake_acc=1.000000
# epoch=68 discriminator_loss=1.402141 real_acc=1.000000 fake_acc=0.000000
# epoch=69 discriminator_loss=1.402695 real_acc=0.000000 fake_acc=1.000000
# epoch=70 discriminator_loss=1.393116 real_acc=0.000000 fake_acc=1.000000
# epoch=71 discriminator_loss=1.397198 real_acc=1.000000 fake_acc=0.000000
# epoch=72 discriminator_loss=1.394622 real_acc=1.000000 fake_acc=0.000000
# epoch=73 discriminator_loss=1.390861 real_acc=0.000000 fake_acc=1.000000
# epoch=74 discriminator_loss=1.397036 real_acc=0.000000 fake_acc=1.000000
# epoch=75 discriminator_loss=1.386297 real_acc=1.000000 fake_acc=0.000000
# epoch=76 discriminator_loss=1.395705 real_acc=1.000000 fake_acc=0.000000
# epoch=77 discriminator_loss=1.386955 real_acc=1.000000 fake_acc=0.000000
# epoch=78 discriminator_loss=1.390285 real_acc=0.000000 fake_acc=1.000000
# epoch=79 discriminator_loss=1.390790 real_acc=0.000000 fake_acc=1.000000
# epoch=80 discriminator_loss=1.386299 real_acc=1.000000 fake_acc=0.000000
# epoch=81 discriminator_loss=1.390512 real_acc=1.000000 fake_acc=0.000000
# epoch=82 discriminator_loss=1.388142 real_acc=1.000000 fake_acc=0.000000
# epoch=83 discriminator_loss=1.386940 real_acc=0.000000 fake_acc=1.000000
# epoch=84 discriminator_loss=1.389576 real_acc=0.000000 fake_acc=1.000000
# epoch=85 discriminator_loss=1.386964 real_acc=0.000000 fake_acc=1.000000
# epoch=86 discriminator_loss=1.387247 real_acc=1.000000 fake_acc=0.000000
# epoch=87 discriminator_loss=1.388609 real_acc=1.000000 fake_acc=0.000000
# epoch=88 discriminator_loss=1.386393 real_acc=1.000000 fake_acc=0.000000
# epoch=89 discriminator_loss=1.387377 real_acc=0.000000 fake_acc=1.000000
# epoch=90 discriminator_loss=1.387742 real_acc=0.000000 fake_acc=1.000000
# epoch=91 discriminator_loss=1.386319 real_acc=0.000000 fake_acc=1.000000
# epoch=92 discriminator_loss=1.387162 real_acc=1.000000 fake_acc=0.000000
# epoch=93 discriminator_loss=1.387263 real_acc=1.000000 fake_acc=0.000000
# epoch=94 discriminator_loss=1.386297 real_acc=1.000000 fake_acc=0.000000
# epoch=95 discriminator_loss=1.386923 real_acc=0.000000 fake_acc=1.000000
# epoch=96 discriminator_loss=1.386986 real_acc=0.000000 fake_acc=1.000000
# epoch=97 discriminator_loss=1.386307 real_acc=0.000000 fake_acc=1.000000
# epoch=98 discriminator_loss=1.386689 real_acc=1.000000 fake_acc=0.000000
# epoch=99 discriminator_loss=1.386824 real_acc=1.000000 fake_acc=0.000000
# epoch=100 discriminator_loss=1.386311 real_acc=1.000000 fake_acc=0.000000
# epoch=101 discriminator_loss=1.386533 real_acc=0.000000 fake_acc=1.000000
# epoch=102 discriminator_loss=1.386702 real_acc=0.000000 fake_acc=1.000000
# epoch=103 discriminator_loss=1.386337 real_acc=0.000000 fake_acc=1.000000
# epoch=104 discriminator_loss=1.386409 real_acc=1.000000 fake_acc=0.000000
# epoch=105 discriminator_loss=1.386595 real_acc=1.000000 fake_acc=0.000000
# epoch=106 discriminator_loss=1.386349 real_acc=1.000000 fake_acc=0.000000
# epoch=107 discriminator_loss=1.386349 real_acc=0.000000 fake_acc=1.000000
# epoch=108 discriminator_loss=1.386513 real_acc=0.000000 fake_acc=1.000000
# epoch=109 discriminator_loss=1.386372 real_acc=0.000000 fake_acc=1.000000
# epoch=110 discriminator_loss=1.386304 real_acc=1.000000 fake_acc=0.000000
# epoch=111 discriminator_loss=1.386444 real_acc=1.000000 fake_acc=0.000000
# epoch=112 discriminator_loss=1.386370 real_acc=1.000000 fake_acc=0.000000
# epoch=113 discriminator_loss=1.386292 real_acc=0.000000 fake_acc=1.000000
# epoch=114 discriminator_loss=1.386390 real_acc=0.000000 fake_acc=1.000000
# epoch=115 discriminator_loss=1.386366 real_acc=0.000000 fake_acc=1.000000
# epoch=116 discriminator_loss=1.386289 real_acc=0.000000 fake_acc=1.000000
# epoch=117 discriminator_loss=1.386354 real_acc=1.000000 fake_acc=0.000000
# epoch=118 discriminator_loss=1.386353 real_acc=1.000000 fake_acc=0.000000
# epoch=119 discriminator_loss=1.386291 real_acc=1.000000 fake_acc=0.000000
# epoch=120 discriminator_loss=1.386328 real_acc=0.000000 fake_acc=1.000000
# epoch=121 discriminator_loss=1.386343 real_acc=0.000000 fake_acc=1.000000
# epoch=122 discriminator_loss=1.386291 real_acc=0.000000 fake_acc=1.000000
# epoch=123 discriminator_loss=1.386313 real_acc=1.000000 fake_acc=0.000000
# epoch=124 discriminator_loss=1.386331 real_acc=1.000000 fake_acc=0.000000
# epoch=125 discriminator_loss=1.386296 real_acc=1.000000 fake_acc=0.000000
# epoch=126 discriminator_loss=1.386305 real_acc=0.000000 fake_acc=1.000000
# epoch=127 discriminator_loss=1.386319 real_acc=0.000000 fake_acc=1.000000
# epoch=128 discriminator_loss=1.386292 real_acc=0.000000 fake_acc=1.000000
# epoch=129 discriminator_loss=1.386290 real_acc=1.000000 fake_acc=0.000000
# epoch=130 discriminator_loss=1.386311 real_acc=1.000000 fake_acc=0.000000
# epoch=131 discriminator_loss=1.386297 real_acc=1.000000 fake_acc=0.000000
# epoch=132 discriminator_loss=1.386295 real_acc=0.000000 fake_acc=1.000000
# epoch=133 discriminator_loss=1.386305 real_acc=0.000000 fake_acc=1.000000
# epoch=134 discriminator_loss=1.386293 real_acc=0.000000 fake_acc=1.000000
# epoch=135 discriminator_loss=1.386288 real_acc=1.000000 fake_acc=0.000000
# epoch=136 discriminator_loss=1.386300 real_acc=1.000000 fake_acc=0.000000
# epoch=137 discriminator_loss=1.386298 real_acc=1.000000 fake_acc=0.000000
# epoch=138 discriminator_loss=1.386285 real_acc=0.000000 fake_acc=1.000000
# epoch=139 discriminator_loss=1.386295 real_acc=0.000000 fake_acc=1.000000
# epoch=140 discriminator_loss=1.386292 real_acc=0.000000 fake_acc=1.000000
# epoch=141 discriminator_loss=1.386286 real_acc=1.000000 fake_acc=0.000000
# epoch=142 discriminator_loss=1.386298 real_acc=1.000000 fake_acc=0.000000
# epoch=143 discriminator_loss=1.386290 real_acc=1.000000 fake_acc=0.000000
# epoch=144 discriminator_loss=1.386294 real_acc=0.000000 fake_acc=1.000000
# epoch=145 discriminator_loss=1.386291 real_acc=0.000000 fake_acc=1.000000
# epoch=146 discriminator_loss=1.386294 real_acc=0.000000 fake_acc=1.000000
# epoch=147 discriminator_loss=1.386286 real_acc=1.000000 fake_acc=0.000000
# epoch=148 discriminator_loss=1.386298 real_acc=1.000000 fake_acc=0.000000
# epoch=149 discriminator_loss=1.386287 real_acc=1.000000 fake_acc=0.000000
# epoch=150 discriminator_loss=1.386296 real_acc=0.000000 fake_acc=1.000000
# epoch=151 discriminator_loss=1.386285 real_acc=0.000000 fake_acc=1.000000
# epoch=152 discriminator_loss=1.386294 real_acc=0.000000 fake_acc=1.000000
# epoch=153 discriminator_loss=1.386287 real_acc=1.000000 fake_acc=0.000000
# epoch=154 discriminator_loss=1.386290 real_acc=1.000000 fake_acc=0.000000
# epoch=155 discriminator_loss=1.386290 real_acc=1.000000 fake_acc=0.000000
# epoch=156 discriminator_loss=1.386288 real_acc=0.000000 fake_acc=1.000000
# epoch=157 discriminator_loss=1.386289 real_acc=0.000000 fake_acc=1.000000
# epoch=158 discriminator_loss=1.386289 real_acc=0.000000 fake_acc=1.000000
# epoch=159 discriminator_loss=1.386290 real_acc=1.000000 fake_acc=0.000000
# epoch=160 discriminator_loss=1.386287 real_acc=1.000000 fake_acc=0.000000
# epoch=161 discriminator_loss=1.386286 real_acc=1.000000 fake_acc=0.000000
# epoch=162 discriminator_loss=1.386285 real_acc=0.000000 fake_acc=1.000000
# epoch=163 discriminator_loss=1.386281 real_acc=0.000000 fake_acc=1.000000
# epoch=164 discriminator_loss=1.386288 real_acc=0.000000 fake_acc=1.000000
# epoch=165 discriminator_loss=1.386280 real_acc=1.000000 fake_acc=0.000000
# epoch=166 discriminator_loss=1.386284 real_acc=1.000000 fake_acc=0.000000
# epoch=167 discriminator_loss=1.386281 real_acc=0.000000 fake_acc=1.000000
# epoch=168 discriminator_loss=1.386289 real_acc=0.000000 fake_acc=1.000000
# epoch=169 discriminator_loss=1.386280 real_acc=0.000000 fake_acc=1.000000
# epoch=170 discriminator_loss=1.386281 real_acc=1.000000 fake_acc=0.000000
# epoch=171 discriminator_loss=1.386291 real_acc=1.000000 fake_acc=0.000000
# epoch=172 discriminator_loss=1.386287 real_acc=1.000000 fake_acc=0.000000
# epoch=173 discriminator_loss=1.386286 real_acc=0.000000 fake_acc=1.000000
# epoch=174 discriminator_loss=1.386284 real_acc=0.000000 fake_acc=1.000000
# epoch=175 discriminator_loss=1.386281 real_acc=0.000000 fake_acc=1.000000
# epoch=176 discriminator_loss=1.386282 real_acc=1.000000 fake_acc=0.000000
# epoch=177 discriminator_loss=1.386284 real_acc=1.000000 fake_acc=0.000000
# epoch=178 discriminator_loss=1.386283 real_acc=1.000000 fake_acc=0.000000
# epoch=179 discriminator_loss=1.386282 real_acc=0.000000 fake_acc=1.000000
# epoch=180 discriminator_loss=1.386278 real_acc=0.000000 fake_acc=1.000000
# epoch=181 discriminator_loss=1.386281 real_acc=1.000000 fake_acc=0.000000
# epoch=182 discriminator_loss=1.386284 real_acc=1.000000 fake_acc=0.000000
# epoch=183 discriminator_loss=1.386282 real_acc=1.000000 fake_acc=0.000000
# epoch=184 discriminator_loss=1.386276 real_acc=0.000000 fake_acc=1.000000
# epoch=185 discriminator_loss=1.386282 real_acc=0.000000 fake_acc=1.000000
# epoch=186 discriminator_loss=1.386287 real_acc=0.000000 fake_acc=1.000000
# epoch=187 discriminator_loss=1.386279 real_acc=1.000000 fake_acc=0.000000
# epoch=188 discriminator_loss=1.386290 real_acc=1.000000 fake_acc=0.000000
# epoch=189 discriminator_loss=1.386277 real_acc=0.000000 fake_acc=1.000000
# epoch=190 discriminator_loss=1.386275 real_acc=0.000000 fake_acc=1.000000
# epoch=191 discriminator_loss=1.386286 real_acc=0.000000 fake_acc=1.000000
# epoch=192 discriminator_loss=1.386276 real_acc=1.000000 fake_acc=0.000000
# epoch=193 discriminator_loss=1.386273 real_acc=1.000000 fake_acc=0.000000
# epoch=194 discriminator_loss=1.386292 real_acc=1.000000 fake_acc=0.000000
# epoch=195 discriminator_loss=1.386283 real_acc=0.000000 fake_acc=1.000000
# epoch=196 discriminator_loss=1.386278 real_acc=0.000000 fake_acc=1.000000
# epoch=197 discriminator_loss=1.386276 real_acc=1.000000 fake_acc=0.000000
# epoch=198 discriminator_loss=1.386276 real_acc=1.000000 fake_acc=0.000000
# epoch=199 discriminator_loss=1.386276 real_acc=1.000000 fake_acc=0.000000
# epoch=200 discriminator_loss=1.386274 real_acc=0.000000 fake_acc=1.000000
# epoch=201 discriminator_loss=1.386278 real_acc=0.000000 fake_acc=1.000000
# epoch=202 discriminator_loss=1.386282 real_acc=1.000000 fake_acc=0.000000
# epoch=203 discriminator_loss=1.386282 real_acc=1.000000 fake_acc=0.000000
# epoch=204 discriminator_loss=1.386277 real_acc=1.000000 fake_acc=0.000000
# epoch=205 discriminator_loss=1.386277 real_acc=0.000000 fake_acc=1.000000
# epoch=206 discriminator_loss=1.386275 real_acc=0.000000 fake_acc=1.000000
# epoch=207 discriminator_loss=1.386275 real_acc=1.000000 fake_acc=0.000000
# epoch=208 discriminator_loss=1.386277 real_acc=1.000000 fake_acc=0.000000
# epoch=209 discriminator_loss=1.386283 real_acc=1.000000 fake_acc=0.000000
# epoch=210 discriminator_loss=1.386280 real_acc=0.000000 fake_acc=1.000000
# epoch=211 discriminator_loss=1.386261 real_acc=0.000000 fake_acc=1.000000
# epoch=212 discriminator_loss=1.386277 real_acc=1.000000 fake_acc=0.000000
# epoch=213 discriminator_loss=1.386280 real_acc=1.000000 fake_acc=0.000000
# epoch=214 discriminator_loss=1.386277 real_acc=1.000000 fake_acc=0.000000
# epoch=215 discriminator_loss=1.386273 real_acc=0.000000 fake_acc=1.000000
# epoch=216 discriminator_loss=1.386273 real_acc=1.000000 fake_acc=1.000000
# epoch=217 discriminator_loss=1.386279 real_acc=1.000000 fake_acc=0.000000
# epoch=218 discriminator_loss=1.386282 real_acc=1.000000 fake_acc=0.000000
# epoch=219 discriminator_loss=1.386263 real_acc=0.000000 fake_acc=1.000000
# epoch=220 discriminator_loss=1.386272 real_acc=0.000000 fake_acc=1.000000
# epoch=221 discriminator_loss=1.386274 real_acc=1.000000 fake_acc=0.000000
# epoch=222 discriminator_loss=1.386264 real_acc=1.000000 fake_acc=0.000000
# epoch=223 discriminator_loss=1.386271 real_acc=1.000000 fake_acc=0.000000
# epoch=224 discriminator_loss=1.386255 real_acc=1.000000 fake_acc=1.000000
# epoch=225 discriminator_loss=1.386266 real_acc=1.000000 fake_acc=0.000000
# epoch=226 discriminator_loss=1.386276 real_acc=1.000000 fake_acc=0.000000
# epoch=227 discriminator_loss=1.386273 real_acc=1.000000 fake_acc=0.000000
# epoch=228 discriminator_loss=1.386288 real_acc=1.000000 fake_acc=0.000000
# epoch=229 discriminator_loss=1.386268 real_acc=0.000000 fake_acc=1.000000
# epoch=230 discriminator_loss=1.386268 real_acc=1.000000 fake_acc=0.000000
# epoch=231 discriminator_loss=1.386267 real_acc=1.000000 fake_acc=0.000000
# epoch=232 discriminator_loss=1.386250 real_acc=1.000000 fake_acc=0.000000
# epoch=233 discriminator_loss=1.386268 real_acc=1.000000 fake_acc=0.000000
# epoch=234 discriminator_loss=1.386255 real_acc=1.000000 fake_acc=1.000000
# epoch=235 discriminator_loss=1.386281 real_acc=1.000000 fake_acc=0.000000
# epoch=236 discriminator_loss=1.386260 real_acc=1.000000 fake_acc=0.000000
# epoch=237 discriminator_loss=1.386268 real_acc=1.000000 fake_acc=0.000000
# epoch=238 discriminator_loss=1.386265 real_acc=1.000000 fake_acc=0.000000
# epoch=239 discriminator_loss=1.386252 real_acc=1.000000 fake_acc=0.000000
# epoch=240 discriminator_loss=1.386272 real_acc=1.000000 fake_acc=0.000000
# epoch=241 discriminator_loss=1.386257 real_acc=1.000000 fake_acc=0.000000
# epoch=242 discriminator_loss=1.386265 real_acc=1.000000 fake_acc=1.000000
# epoch=243 discriminator_loss=1.386254 real_acc=1.000000 fake_acc=0.000000
# epoch=244 discriminator_loss=1.386254 real_acc=1.000000 fake_acc=0.000000
# epoch=245 discriminator_loss=1.386255 real_acc=1.000000 fake_acc=0.000000
# epoch=246 discriminator_loss=1.386258 real_acc=1.000000 fake_acc=1.000000
# epoch=247 discriminator_loss=1.386254 real_acc=1.000000 fake_acc=0.000000
# epoch=248 discriminator_loss=1.386252 real_acc=1.000000 fake_acc=0.000000
# epoch=249 discriminator_loss=1.386241 real_acc=1.000000 fake_acc=0.000000
# epoch=250 discriminator_loss=1.386240 real_acc=1.000000 fake_acc=0.000000
# epoch=251 discriminator_loss=1.386256 real_acc=1.000000 fake_acc=0.000000
# epoch=252 discriminator_loss=1.386244 real_acc=1.000000 fake_acc=0.000000
# epoch=253 discriminator_loss=1.386245 real_acc=1.000000 fake_acc=0.000000
# epoch=254 discriminator_loss=1.386240 real_acc=1.000000 fake_acc=0.000000
# epoch=255 discriminator_loss=1.386267 real_acc=1.000000 fake_acc=0.000000
# epoch=256 discriminator_loss=1.386247 real_acc=1.000000 fake_acc=1.000000
# epoch=257 discriminator_loss=1.386228 real_acc=1.000000 fake_acc=0.000000
# epoch=258 discriminator_loss=1.386244 real_acc=1.000000 fake_acc=0.000000
# epoch=259 discriminator_loss=1.386247 real_acc=1.000000 fake_acc=0.000000
# epoch=260 discriminator_loss=1.386228 real_acc=1.000000 fake_acc=1.000000
# epoch=261 discriminator_loss=1.386231 real_acc=1.000000 fake_acc=0.000000
# epoch=262 discriminator_loss=1.386246 real_acc=1.000000 fake_acc=0.000000
# epoch=263 discriminator_loss=1.386225 real_acc=1.000000 fake_acc=1.000000
# epoch=264 discriminator_loss=1.386227 real_acc=1.000000 fake_acc=0.000000
# epoch=265 discriminator_loss=1.386218 real_acc=1.000000 fake_acc=0.000000
# epoch=266 discriminator_loss=1.386240 real_acc=1.000000 fake_acc=0.000000
# epoch=267 discriminator_loss=1.386225 real_acc=0.000000 fake_acc=1.000000
# epoch=268 discriminator_loss=1.386204 real_acc=1.000000 fake_acc=0.000000
# epoch=269 discriminator_loss=1.386229 real_acc=1.000000 fake_acc=0.000000
# epoch=270 discriminator_loss=1.386208 real_acc=0.000000 fake_acc=1.000000
# epoch=271 discriminator_loss=1.386181 real_acc=1.000000 fake_acc=0.000000
# epoch=272 discriminator_loss=1.386169 real_acc=1.000000 fake_acc=0.000000
# epoch=273 discriminator_loss=1.386190 real_acc=1.000000 fake_acc=0.000000
# epoch=274 discriminator_loss=1.386168 real_acc=1.000000 fake_acc=1.000000
# epoch=275 discriminator_loss=1.386180 real_acc=1.000000 fake_acc=0.000000
# epoch=276 discriminator_loss=1.386178 real_acc=1.000000 fake_acc=1.000000
# epoch=277 discriminator_loss=1.386129 real_acc=1.000000 fake_acc=1.000000
# epoch=278 discriminator_loss=1.386156 real_acc=1.000000 fake_acc=0.000000
# epoch=279 discriminator_loss=1.386136 real_acc=0.000000 fake_acc=1.000000
# epoch=280 discriminator_loss=1.386182 real_acc=1.000000 fake_acc=0.000000
# epoch=281 discriminator_loss=1.386195 real_acc=1.000000 fake_acc=0.000000
# epoch=282 discriminator_loss=1.386147 real_acc=0.000000 fake_acc=1.000000
# epoch=283 discriminator_loss=1.386136 real_acc=1.000000 fake_acc=0.000000
# epoch=284 discriminator_loss=1.386091 real_acc=1.000000 fake_acc=1.000000
# epoch=285 discriminator_loss=1.386203 real_acc=1.000000 fake_acc=0.000000
# epoch=286 discriminator_loss=1.386115 real_acc=0.000000 fake_acc=1.000000
# epoch=287 discriminator_loss=1.386106 real_acc=1.000000 fake_acc=0.000000
# epoch=288 discriminator_loss=1.386046 real_acc=0.000000 fake_acc=1.000000
# epoch=289 discriminator_loss=1.386058 real_acc=1.000000 fake_acc=0.000000
# epoch=290 discriminator_loss=1.386111 real_acc=0.000000 fake_acc=1.000000
# epoch=291 discriminator_loss=1.386058 real_acc=1.000000 fake_acc=0.000000
# epoch=292 discriminator_loss=1.386101 real_acc=0.000000 fake_acc=1.000000
# epoch=293 discriminator_loss=1.386268 real_acc=1.000000 fake_acc=0.000000
# epoch=294 discriminator_loss=1.387272 real_acc=0.000000 fake_acc=1.000000
# epoch=295 discriminator_loss=1.391606 real_acc=1.000000 fake_acc=0.000000
# epoch=296 discriminator_loss=1.414476 real_acc=0.000000 fake_acc=1.000000
# epoch=297 discriminator_loss=1.386732 real_acc=0.000000 fake_acc=1.000000
# epoch=298 discriminator_loss=1.408607 real_acc=1.000000 fake_acc=0.000000
# epoch=299 discriminator_loss=1.390246 real_acc=1.000000 fake_acc=0.000000
# epoch=300 discriminator_loss=1.395243 real_acc=0.000000 fake_acc=1.000000
# epoch=301 discriminator_loss=1.394684 real_acc=0.000000 fake_acc=1.000000
# epoch=302 discriminator_loss=1.390511 real_acc=1.000000 fake_acc=0.000000
# epoch=303 discriminator_loss=1.394131 real_acc=1.000000 fake_acc=0.000000
# epoch=304 discriminator_loss=1.389076 real_acc=0.000000 fake_acc=1.000000
# epoch=305 discriminator_loss=1.393997 real_acc=0.000000 fake_acc=1.000000
# epoch=306 discriminator_loss=1.386407 real_acc=0.000000 fake_acc=1.000000
# epoch=307 discriminator_loss=1.392240 real_acc=1.000000 fake_acc=0.000000
# epoch=308 discriminator_loss=1.388375 real_acc=1.000000 fake_acc=0.000000
# epoch=309 discriminator_loss=1.387588 real_acc=0.000000 fake_acc=1.000000
# epoch=310 discriminator_loss=1.390302 real_acc=0.000000 fake_acc=1.000000
# epoch=311 discriminator_loss=1.386746 real_acc=0.000000 fake_acc=1.000000
# epoch=312 discriminator_loss=1.387954 real_acc=1.000000 fake_acc=0.000000
# epoch=313 discriminator_loss=1.388924 real_acc=1.000000 fake_acc=0.000000
# epoch=314 discriminator_loss=1.386282 real_acc=1.000000 fake_acc=0.000000
# epoch=315 discriminator_loss=1.387920 real_acc=0.000000 fake_acc=1.000000
# epoch=316 discriminator_loss=1.387887 real_acc=0.000000 fake_acc=1.000000
# epoch=317 discriminator_loss=1.386275 real_acc=0.000000 fake_acc=1.000000
# epoch=318 discriminator_loss=1.387482 real_acc=1.000000 fake_acc=0.000000
# epoch=319 discriminator_loss=1.387376 real_acc=1.000000 fake_acc=0.000000
# epoch=320 discriminator_loss=1.386277 real_acc=0.000000 fake_acc=1.000000
# epoch=321 discriminator_loss=1.387074 real_acc=0.000000 fake_acc=1.000000
# epoch=322 discriminator_loss=1.387103 real_acc=0.000000 fake_acc=1.000000
# epoch=323 discriminator_loss=1.386292 real_acc=0.000000 fake_acc=1.000000
# epoch=324 discriminator_loss=1.386700 real_acc=1.000000 fake_acc=0.000000
# epoch=325 discriminator_loss=1.386956 real_acc=1.000000 fake_acc=0.000000
# epoch=326 discriminator_loss=1.386353 real_acc=1.000000 fake_acc=0.000000
# epoch=327 discriminator_loss=1.386453 real_acc=0.000000 fake_acc=1.000000
# epoch=328 discriminator_loss=1.386773 real_acc=0.000000 fake_acc=1.000000
# epoch=329 discriminator_loss=1.386430 real_acc=0.000000 fake_acc=1.000000
# epoch=330 discriminator_loss=1.386299 real_acc=1.000000 fake_acc=0.000000
# epoch=331 discriminator_loss=1.386587 real_acc=1.000000 fake_acc=0.000000
# epoch=332 discriminator_loss=1.386492 real_acc=1.000000 fake_acc=0.000000
# epoch=333 discriminator_loss=1.386266 real_acc=1.000000 fake_acc=0.000000
# epoch=334 discriminator_loss=1.386422 real_acc=0.000000 fake_acc=1.000000
# epoch=335 discriminator_loss=1.386487 real_acc=0.000000 fake_acc=1.000000
# epoch=336 discriminator_loss=1.386302 real_acc=0.000000 fake_acc=1.000000
# epoch=337 discriminator_loss=1.386300 real_acc=1.000000 fake_acc=0.000000
# epoch=338 discriminator_loss=1.386446 real_acc=1.000000 fake_acc=0.000000
# epoch=339 discriminator_loss=1.386350 real_acc=1.000000 fake_acc=0.000000
# epoch=340 discriminator_loss=1.386260 real_acc=0.000000 fake_acc=1.000000
# epoch=341 discriminator_loss=1.386360 real_acc=0.000000 fake_acc=1.000000
# epoch=342 discriminator_loss=1.386347 real_acc=0.000000 fake_acc=1.000000
# epoch=343 discriminator_loss=1.386266 real_acc=0.000000 fake_acc=1.000000
# epoch=344 discriminator_loss=1.386292 real_acc=1.000000 fake_acc=0.000000
# epoch=345 discriminator_loss=1.386344 real_acc=1.000000 fake_acc=0.000000
# epoch=346 discriminator_loss=1.386280 real_acc=1.000000 fake_acc=0.000000
# epoch=347 discriminator_loss=1.386265 real_acc=0.000000 fake_acc=1.000000
# epoch=348 discriminator_loss=1.386302 real_acc=0.000000 fake_acc=1.000000
# epoch=349 discriminator_loss=1.386297 real_acc=0.000000 fake_acc=1.000000
# epoch=350 discriminator_loss=1.386258 real_acc=0.000000 fake_acc=1.000000
# epoch=351 discriminator_loss=1.386270 real_acc=1.000000 fake_acc=0.000000
# epoch=352 discriminator_loss=1.386276 real_acc=1.000000 fake_acc=0.000000
# epoch=353 discriminator_loss=1.386240 real_acc=1.000000 fake_acc=0.000000
# epoch=354 discriminator_loss=1.386232 real_acc=0.000000 fake_acc=1.000000
# epoch=355 discriminator_loss=1.386275 real_acc=0.000000 fake_acc=1.000000
# epoch=356 discriminator_loss=1.386262 real_acc=0.000000 fake_acc=1.000000
# epoch=357 discriminator_loss=1.386243 real_acc=1.000000 fake_acc=0.000000
# epoch=358 discriminator_loss=1.386237 real_acc=1.000000 fake_acc=0.000000
# epoch=359 discriminator_loss=1.386253 real_acc=1.000000 fake_acc=0.000000
# epoch=360 discriminator_loss=1.386216 real_acc=1.000000 fake_acc=0.000000
# epoch=361 discriminator_loss=1.386245 real_acc=0.000000 fake_acc=1.000000
# epoch=362 discriminator_loss=1.386236 real_acc=0.000000 fake_acc=1.000000
# epoch=363 discriminator_loss=1.386209 real_acc=0.000000 fake_acc=1.000000
# epoch=364 discriminator_loss=1.386192 real_acc=1.000000 fake_acc=0.000000
# epoch=365 discriminator_loss=1.386192 real_acc=1.000000 fake_acc=0.000000
# epoch=366 discriminator_loss=1.386213 real_acc=1.000000 fake_acc=0.000000
# epoch=367 discriminator_loss=1.386154 real_acc=0.000000 fake_acc=1.000000
# epoch=368 discriminator_loss=1.386172 real_acc=0.000000 fake_acc=1.000000
# epoch=369 discriminator_loss=1.386140 real_acc=0.000000 fake_acc=1.000000
# epoch=370 discriminator_loss=1.386202 real_acc=1.000000 fake_acc=0.000000
# epoch=371 discriminator_loss=1.386164 real_acc=1.000000 fake_acc=0.000000
# epoch=372 discriminator_loss=1.386137 real_acc=1.000000 fake_acc=0.000000
# epoch=373 discriminator_loss=1.386167 real_acc=0.000000 fake_acc=1.000000
# epoch=374 discriminator_loss=1.386162 real_acc=0.000000 fake_acc=1.000000
# epoch=375 discriminator_loss=1.386127 real_acc=0.000000 fake_acc=1.000000
# epoch=376 discriminator_loss=1.386092 real_acc=1.000000 fake_acc=0.000000
# epoch=377 discriminator_loss=1.386129 real_acc=1.000000 fake_acc=0.000000
# epoch=378 discriminator_loss=1.386055 real_acc=1.000000 fake_acc=1.000000
# epoch=379 discriminator_loss=1.386144 real_acc=0.000000 fake_acc=1.000000
# epoch=380 discriminator_loss=1.386029 real_acc=0.000000 fake_acc=1.000000
# epoch=381 discriminator_loss=1.386041 real_acc=0.000000 fake_acc=1.000000
# epoch=382 discriminator_loss=1.385912 real_acc=1.000000 fake_acc=0.000000
# epoch=383 discriminator_loss=1.385920 real_acc=1.000000 fake_acc=1.000000
# epoch=384 discriminator_loss=1.385841 real_acc=0.000000 fake_acc=1.000000
# epoch=385 discriminator_loss=1.385756 real_acc=0.000000 fake_acc=1.000000
# epoch=386 discriminator_loss=1.385690 real_acc=0.000000 fake_acc=1.000000
# epoch=387 discriminator_loss=1.385589 real_acc=1.000000 fake_acc=1.000000
# epoch=388 discriminator_loss=1.385466 real_acc=0.000000 fake_acc=1.000000
# epoch=389 discriminator_loss=1.385472 real_acc=0.000000 fake_acc=1.000000
# epoch=390 discriminator_loss=1.385274 real_acc=0.000000 fake_acc=1.000000
# epoch=391 discriminator_loss=1.385313 real_acc=0.000000 fake_acc=1.000000
# epoch=392 discriminator_loss=1.384903 real_acc=0.000000 fake_acc=1.000000
# epoch=393 discriminator_loss=1.384071 real_acc=1.000000 fake_acc=1.000000
# epoch=394 discriminator_loss=1.382481 real_acc=0.000000 fake_acc=1.000000
# epoch=395 discriminator_loss=1.381658 real_acc=1.000000 fake_acc=0.000000
# epoch=396 discriminator_loss=1.390222 real_acc=0.000000 fake_acc=1.000000
# epoch=397 discriminator_loss=1.477657 real_acc=1.000000 fake_acc=0.000000
# epoch=398 discriminator_loss=1.386295 real_acc=0.000000 fake_acc=1.000000
# epoch=399 discriminator_loss=1.410547 real_acc=0.000000 fake_acc=1.000000
# epoch=400 discriminator_loss=1.386507 real_acc=0.000000 fake_acc=1.000000
# epoch=401 discriminator_loss=1.443449 real_acc=1.000000 fake_acc=0.000000
# epoch=402 discriminator_loss=1.457608 real_acc=0.000000 fake_acc=1.000000
# epoch=403 discriminator_loss=1.420285 real_acc=0.000000 fake_acc=1.000000
# epoch=404 discriminator_loss=1.416449 real_acc=1.000000 fake_acc=0.000000
# epoch=405 discriminator_loss=1.387200 real_acc=1.000000 fake_acc=0.000000
# epoch=406 discriminator_loss=1.390598 real_acc=0.000000 fake_acc=1.000000
# epoch=407 discriminator_loss=1.387617 real_acc=1.000000 fake_acc=0.000000
# epoch=408 discriminator_loss=1.396607 real_acc=1.000000 fake_acc=0.000000
# epoch=409 discriminator_loss=1.394510 real_acc=0.000000 fake_acc=1.000000
# epoch=410 discriminator_loss=1.400489 real_acc=0.000000 fake_acc=1.000000
# epoch=411 discriminator_loss=1.389754 real_acc=0.000000 fake_acc=1.000000
# epoch=412 discriminator_loss=1.392266 real_acc=1.000000 fake_acc=0.000000
# epoch=413 discriminator_loss=1.394826 real_acc=1.000000 fake_acc=0.000000
# epoch=414 discriminator_loss=1.390814 real_acc=0.000000 fake_acc=1.000000
# epoch=415 discriminator_loss=1.392740 real_acc=0.000000 fake_acc=1.000000
# epoch=416 discriminator_loss=1.388175 real_acc=1.000000 fake_acc=0.000000
# epoch=417 discriminator_loss=1.392759 real_acc=1.000000 fake_acc=0.000000
# epoch=418 discriminator_loss=1.386711 real_acc=1.000000 fake_acc=0.000000
# epoch=419 discriminator_loss=1.390032 real_acc=0.000000 fake_acc=1.000000
# epoch=420 discriminator_loss=1.388679 real_acc=0.000000 fake_acc=1.000000
# epoch=421 discriminator_loss=1.386672 real_acc=1.000000 fake_acc=0.000000
# epoch=422 discriminator_loss=1.388643 real_acc=1.000000 fake_acc=0.000000
# epoch=423 discriminator_loss=1.387796 real_acc=1.000000 fake_acc=0.000000
# epoch=424 discriminator_loss=1.386376 real_acc=0.000000 fake_acc=1.000000
# epoch=425 discriminator_loss=1.387335 real_acc=0.000000 fake_acc=1.000000
# epoch=426 discriminator_loss=1.387621 real_acc=0.000000 fake_acc=1.000000
# epoch=427 discriminator_loss=1.386561 real_acc=0.000000 fake_acc=1.000000
# epoch=428 discriminator_loss=1.386423 real_acc=1.000000 fake_acc=0.000000
# epoch=429 discriminator_loss=1.387145 real_acc=1.000000 fake_acc=0.000000
# epoch=430 discriminator_loss=1.386916 real_acc=1.000000 fake_acc=0.000000
# epoch=431 discriminator_loss=1.386288 real_acc=1.000000 fake_acc=0.000000
# epoch=432 discriminator_loss=1.386461 real_acc=0.000000 fake_acc=1.000000
# epoch=433 discriminator_loss=1.386841 real_acc=0.000000 fake_acc=1.000000
# epoch=434 discriminator_loss=1.386501 real_acc=0.000000 fake_acc=1.000000
# epoch=435 discriminator_loss=1.386158 real_acc=0.000000 fake_acc=1.000000
# epoch=436 discriminator_loss=1.386450 real_acc=1.000000 fake_acc=0.000000
# epoch=437 discriminator_loss=1.386630 real_acc=1.000000 fake_acc=0.000000
# epoch=438 discriminator_loss=1.386309 real_acc=1.000000 fake_acc=0.000000
# epoch=439 discriminator_loss=1.386148 real_acc=0.000000 fake_acc=1.000000
# epoch=440 discriminator_loss=1.386404 real_acc=0.000000 fake_acc=1.000000
# epoch=441 discriminator_loss=1.386430 real_acc=0.000000 fake_acc=1.000000
# epoch=442 discriminator_loss=1.386177 real_acc=0.000000 fake_acc=1.000000
# epoch=443 discriminator_loss=1.386134 real_acc=1.000000 fake_acc=0.000000
# epoch=444 discriminator_loss=1.386289 real_acc=1.000000 fake_acc=0.000000
# epoch=445 discriminator_loss=1.386249 real_acc=1.000000 fake_acc=0.000000
# epoch=446 discriminator_loss=1.386127 real_acc=1.000000 fake_acc=1.000000
# epoch=447 discriminator_loss=1.386267 real_acc=0.000000 fake_acc=1.000000
# epoch=448 discriminator_loss=1.386211 real_acc=0.000000 fake_acc=1.000000
# epoch=449 discriminator_loss=1.386075 real_acc=0.000000 fake_acc=1.000000
# epoch=450 discriminator_loss=1.386104 real_acc=1.000000 fake_acc=0.000000
# epoch=451 discriminator_loss=1.386196 real_acc=1.000000 fake_acc=0.000000
# epoch=452 discriminator_loss=1.386002 real_acc=1.000000 fake_acc=0.000000
# epoch=453 discriminator_loss=1.386092 real_acc=0.000000 fake_acc=1.000000
# epoch=454 discriminator_loss=1.386058 real_acc=0.000000 fake_acc=1.000000
# epoch=455 discriminator_loss=1.386004 real_acc=0.000000 fake_acc=1.000000
# epoch=456 discriminator_loss=1.385950 real_acc=1.000000 fake_acc=0.000000
# epoch=457 discriminator_loss=1.385974 real_acc=1.000000 fake_acc=0.000000
# epoch=458 discriminator_loss=1.386006 real_acc=1.000000 fake_acc=0.000000
# epoch=459 discriminator_loss=1.385914 real_acc=0.000000 fake_acc=1.000000
# epoch=460 discriminator_loss=1.385927 real_acc=0.000000 fake_acc=1.000000
# epoch=461 discriminator_loss=1.385843 real_acc=0.000000 fake_acc=1.000000
# epoch=462 discriminator_loss=1.385643 real_acc=1.000000 fake_acc=0.000000
# epoch=463 discriminator_loss=1.385767 real_acc=1.000000 fake_acc=0.000000
# epoch=464 discriminator_loss=1.385685 real_acc=1.000000 fake_acc=0.000000
# epoch=465 discriminator_loss=1.385776 real_acc=0.000000 fake_acc=1.000000
# epoch=466 discriminator_loss=1.385496 real_acc=0.000000 fake_acc=1.000000
# epoch=467 discriminator_loss=1.385486 real_acc=1.000000 fake_acc=0.000000
# epoch=468 discriminator_loss=1.385567 real_acc=1.000000 fake_acc=0.000000
# epoch=469 discriminator_loss=1.385401 real_acc=0.000000 fake_acc=1.000000
# epoch=470 discriminator_loss=1.385253 real_acc=0.000000 fake_acc=1.000000
# epoch=471 discriminator_loss=1.385529 real_acc=1.000000 fake_acc=0.000000
# epoch=472 discriminator_loss=1.384711 real_acc=0.000000 fake_acc=1.000000
# epoch=473 discriminator_loss=1.384592 real_acc=1.000000 fake_acc=0.000000
# epoch=474 discriminator_loss=1.383572 real_acc=1.000000 fake_acc=0.000000
# epoch=475 discriminator_loss=1.383174 real_acc=0.000000 fake_acc=1.000000
# epoch=476 discriminator_loss=1.385228 real_acc=1.000000 fake_acc=0.000000
# epoch=477 discriminator_loss=1.421732 real_acc=0.000000 fake_acc=1.000000
# epoch=478 discriminator_loss=1.390747 real_acc=0.000000 fake_acc=1.000000
# epoch=479 discriminator_loss=1.400411 real_acc=1.000000 fake_acc=0.000000
# epoch=480 discriminator_loss=1.400031 real_acc=1.000000 fake_acc=0.000000
# epoch=481 discriminator_loss=1.385896 real_acc=1.000000 fake_acc=0.000000
# epoch=482 discriminator_loss=1.385559 real_acc=1.000000 fake_acc=0.000000
# epoch=483 discriminator_loss=1.385725 real_acc=0.000000 fake_acc=1.000000
# epoch=484 discriminator_loss=1.385904 real_acc=0.000000 fake_acc=1.000000
# epoch=485 discriminator_loss=1.386084 real_acc=1.000000 fake_acc=0.000000
# epoch=486 discriminator_loss=1.386029 real_acc=1.000000 fake_acc=0.000000
# epoch=487 discriminator_loss=1.385873 real_acc=1.000000 fake_acc=0.000000
# epoch=488 discriminator_loss=1.385725 real_acc=1.000000 fake_acc=0.000000
# epoch=489 discriminator_loss=1.385724 real_acc=0.000000 fake_acc=1.000000
# epoch=490 discriminator_loss=1.385687 real_acc=0.000000 fake_acc=1.000000
# epoch=491 discriminator_loss=1.385185 real_acc=1.000000 fake_acc=0.000000
# epoch=492 discriminator_loss=1.385689 real_acc=1.000000 fake_acc=0.000000
# epoch=493 discriminator_loss=1.385159 real_acc=1.000000 fake_acc=0.000000
# epoch=494 discriminator_loss=1.384786 real_acc=0.000000 fake_acc=1.000000
# epoch=495 discriminator_loss=1.384128 real_acc=1.000000 fake_acc=1.000000
# epoch=496 discriminator_loss=1.383839 real_acc=1.000000 fake_acc=0.000000
# epoch=497 discriminator_loss=1.384013 real_acc=1.000000 fake_acc=0.000000
# epoch=498 discriminator_loss=1.382404 real_acc=0.000000 fake_acc=1.000000
# epoch=499 discriminator_loss=1.381912 real_acc=1.000000 fake_acc=0.000000
# epoch=500 discriminator_loss=1.380114 real_acc=0.000000 fake_acc=1.000000

# %%
B = 20
W = np.hamming(B)
W /= W.sum()
plt.figure(figsize = (21,8))
plt.plot(range(len(real_acc)),np.convolve(real_acc, W, mode='same'),label='real')
plt.plot(range(len(real_acc)),np.convolve(fake_acc, W, mode='same'),label='fake')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (21,8))
plt.plot(range(len(real_acc)), (np.array(real_acc)+np.array(fake_acc))/2)
